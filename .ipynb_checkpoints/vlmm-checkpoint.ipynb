# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import hmms

# %%
# %matplotlib inline
from nxpd import draw

# %%
import pickle
import helper_functions as hf

# %%
import os     
os.environ["PATH"] += os.pathsep + 'C:\\Anaconda3\\Library\\bin\\graphviz'

# %%
k = hf.load_pickle('seq_events.txt')
# Out:
# pickle loading complete

# %%
hf.sample_per_seq(k, 2000)
# Out:
# Top maximum number of sequence length:
#
#     length  no of samples
# 0      2.0         5237.0
# 1      4.0         4959.0
# 2    199.0         3032.0
# 3      5.0         1903.0
# 4      3.0         1481.0
# 5     71.0          659.0
# 6     31.0          637.0
# 7    129.0          625.0
# 8      6.0          549.0
# 9     23.0          482.0
# 10   194.0          443.0
# 11   197.0          418.0
# 12    15.0          326.0
# 13    19.0          306.0
# 14    69.0          188.0
# 15    26.0          119.0
# 16     7.0          114.0
# 17    16.0          112.0
# 18    11.0           65.0
# 19    13.0           65.0

# %%
length = 7
data_7 = hf.desired_seq(k, length)
# Out:
# ...
# total samples found: 114
#
# few samples of data of sequence length 7
# [[16  1 14 10 10  9 15]
#  [16  1 14  0 12 11 15]
#  [16  1 14 10 10  9 15]
#  [16  1 14  0 12 11 15]
#  [16  1 14  0 12 11 15]]

# %%
length = 6
data_6 = hf.desired_seq(k, length)
# Out:
# ...
# total samples found: 549
#
# few samples of data of sequence length 6
# [[16 14 12  3 11 15]
#  [16 14 12  3 11 15]
#  [16  1 14 10  9 15]
#  [16  1 14 10  9 15]
#  [16 14 12  3 11 15]]

# %%
data6=list(map(array1,data_6))
data7=list(map(array1,data_7))

# %%
data1=data6+data7

# %%
array1=lambda x:np.array(x)

# %%
data1=list(map(array1,data))

# %%
data1
# Out:
# [array([16, 14, 12,  3, 11, 15]),
#  array([16, 14, 12,  3, 11, 15]),
#  array([16,  1, 14, 10,  9, 15]),
#  array([16,  1, 14, 10,  9, 15]),
#  array([16, 14, 12,  3, 11, 15]),
#  array([16,  1, 14, 10,  9, 15]),
#  array([16,  1, 14, 10,  9, 15]),
#  array([16, 14, 12,  3, 11, 15]),
#  array([16,  1, 14, 10,  9, 15]),
#  array([16, 14, 12,  3, 11, 15]),
#  array([16, 14, 12,  3, 11, 15]),
#  array([16,  1, 14, 10,  9, 15]),
#  array([16,  1, 14, 10,  9, 15]),
#  array([16,  1, 14, 10,  9, 15]),
#  array([16,  1, 14, 10,  9, 15]),
#  array([16, 14, 12,  3, 11, 15]),
#  array([16, 14, 12,  3, 11, 15]),
#  array([16, 14, 12,  3, 11, 15]),
#  array([16,  1, 14, 10,  9, 15]),
#  array([16, 14, 12,  3, 11, 15]),
#  array([16, 14, 12,  3, 11, 15]),
#  array([16,  1, 14, 10,  9, 15]),
#  array([16, 14, 12,  3, 11, 15]),
#  array([16,  1, 14, 10,  9, 15]),
#  array([16, 14, 12,  3, 11, 15]),
#  array([16,  1, 14, 10,  9, 15]),
#  array([16, 14, 12,  3, 11, 15]),
# ...

# %%
dhmm_r = hmms.DtHMM.random( 17 ,17)
graph_l = dhmm_r.baum_welch( data1, 100, est=True )
np.exp( dhmm_r.data_estimate(data1) )
# Out:
# iteration  32764 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# iteration  17 / 100
# ...

# %%
hmms.print_parameters( dhmm_r )
# Out:
# Initial probabilities (π) :
#                 0
# 0    0.000000e+00
# 1    7.541478e-03
# 2    0.000000e+00
# 3    0.000000e+00
# 4   1.765853e-251
# 5    0.000000e+00
# 6    0.000000e+00
# 7    0.000000e+00
# 8    0.000000e+00
# 9    0.000000e+00
# 10  1.393328e-230
# 11   0.000000e+00
# 12   0.000000e+00
# 13   9.924585e-01
# 14   0.000000e+00
# 15   0.000000e+00
# 16   0.000000e+00
# Transition probabilities matrix (A):
#           0              1    2              3              4         5   \
# 0   0.000000   0.000000e+00  0.0   0.000000e+00   0.000000e+00  0.000000
# 1   0.000000   1.369624e-01  0.0   7.207838e-62   2.665571e-55  0.000000
# 2   1.000000   0.000000e+00  0.0   0.000000e+00   0.000000e+00  0.000000
# 3   0.000000   0.000000e+00  0.0   7.950589e-01   2.035468e-01  0.000000
# 4   0.000000   2.703700e-84  0.0   4.995026e-01   6.001738e-02  0.000000
# 5   0.000000   0.000000e+00  1.0   0.000000e+00   0.000000e+00  0.000000
# ...

# %%
plt.plot( graph_l )

# %%
seq_len = 7
s_seq, e_seq = dhmm_r.generate( seq_len )

#resize plot
plt.rcParams['figure.figsize'] = [7,7]

hmms.plot_hmm( s_seq, e_seq )

# %%
e_seq_l=list(e_seq)
e_seq_l
# Out:
# [16, 1, 14, 10, 9, 15, 15]

# %%
draw(hf.plot_seq(e_seq), show='ipynb')
